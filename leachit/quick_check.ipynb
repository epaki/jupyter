# %%
# Open a parquet file and print the first 5 rows
import pandas as pd

# print the current working directory
import os
print(f"Current working directory: {os.getcwd()}")

# create a path, joining the folders 'backend', 'data', 'sites','shanta','new_luika'

path = os.path.join(os.getcwd(), 'backend', 'data', 'sites','shanta','new_luika')

df = pd.read_parquet(os.path.join(path, 'historical.parquet'))
# df = pd.read_parquet('historical.parquet')

# print date range of the data
print(f"Date range: {df['date'].min()} to {df['date'].max()}")

# print statistics of the data
print(df.describe())
# Out:
# Current working directory: c:\GitHubRepositories\leachit_ep
# Date range: 2024-06-01 to 2025-08-31
#        percent_solids  wad_cn_tailings_ppm  ph_leach_tank_01  \
# count      457.000000           457.000000        436.000000
# mean        49.660025           223.494311         11.477959
# std          3.759995           142.904760          0.487423
# min         31.000000             0.000000          6.260000
# 25%         49.476190           160.000000         11.182500
# 50%         50.666667           224.000000         11.520000
# 75%         51.291667           296.000000         11.775000
# max         61.000000           804.000000         12.860000
#
#        ph_leach_tank_02  ph_cil_tank_01  ph_cil_tank_02  ph_cil_tank_03  \
# count        457.000000      457.000000      457.000000      457.000000
# mean          11.610115       11.523611       11.537455       11.481258
# std            2.382210        0.396212        0.396834        0.335063
# ...
