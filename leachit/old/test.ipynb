# %%
# Create df_clean from full_inverse_solver_results_final.csv
import pandas as pd
import plotting_functions as pf

# Read the CSV file
df = pd.read_csv('full_inverse_solver_results_final.csv')

# %%
pf.plot_comparative_heatmap_surface(
    df=df,
    left_fields={
        "x_field": "Leach_Cn_Adds_ppm",
        "y_field": "Leach_Feed_Grade_Au_Gt_Day",
        "z_field": "Au_Recovery_pct",
        "x_label": "CN Concentration (ppm)",
        "y_label": "Au Grade (g/t)",
        "z_label": "Actual Recovery (%)"
    },
    right_fields={
        "x_field": "Leach_Cn_Adds_ppm",
        "y_field": "Leach_Feed_Grade_Au_Gt_Day",
        "z_field": "Predicted_Recovery_Enhanced",
        "x_label": "CN Concentration (ppm)",
        "y_label": "Au Grade (g/t)",
        "z_label": "Predicted Recovery (%)"
    },
    bins=30,
    grid_points=100,
    clip_range=(70, 95)
)

# %%
pf.plot_comparative_heatmap_surface(
    df=df,
    left_fields={
        "x_field": "Effective_Particle_Size_um",
        "y_field": "Leach_Feed_Grade_Au_Gt_Day",
        "z_field": "Au_Recovery_pct",
        "x_label": "Particle Size (um)",
        "y_label": "Au Grade (g/t)",
        "z_label": "Actual Recovery (%)"
    },
    right_fields={
        "x_field": "Leach_Cn_Adds_ppm",
        "y_field": "Effective_Particle_Size_um",
        "z_field": "Predicted_Recovery_Enhanced",
        "x_label": "CN Concentration (ppm)",
        "y_label": "Particle Size (um)",
        "z_label": "Predicted Recovery (%)"
    },
    bins=30,
    grid_points=100,
    clip_range=(70, 95)
)
